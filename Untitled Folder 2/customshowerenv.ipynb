# %%
##building own environment
import gym
from gym import Env
from gym.spaces import Discrete, Box,Dict, Tuple, MultiBinary, MultiDiscrete

#import helpers
import numpy as np
import random
import os

#import  stable baselines stuff
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %%
#build an agent to give us the best shower possible

# %%
#randomly temperature

# %%
#37-39 degree

# %%
class showerEnv(Env):
    def __init__(self):
        self.action_space = Discrete(3)
        self.observation_space = Box(low =0, high = 100, shape = (1,))
        self.state = 38 + random.randint(-3,3)
        self.shower_length = 60
    def step(self,action):
        self.state += action-1
        self.shower_length -=1
        if self.state >= 37 and self.state <=39:
            reward = 1
        else:
            reward = -1
        
        if self.shower_length <= 0:
            done = True
        else:
            done = False
        info = {}
        
        return self.state,reward,done,info
        
    def render(self):
        ## show the current state and env
        pass
    def reset(self):
        self.state = 38 + random.randint(-3,3)
        self.shower_length = 60
        return self.state
        pass

# %%
env = showerEnv()

# %%
env.observation_space.sample()
# Out:
# array([75.651955], dtype=float32)

# %%
env.action_space.sample()
# Out:
# 1

# %%
episodes = 5
for episode in range(1,episodes+1):
    obs = env.reset()
    done = False
    score = 0
     
    while not done:
        env.render()
        action = env.action_space.sample()
        obs,reward,done,info = env.step(action)
        score += reward
    print('Episode: {}, Score: {}'.format(episode,score))
# Out:
# Episode: 1, Score: -50
# Episode: 2, Score: -56
# Episode: 3, Score: -16
# Episode: 4, Score: -60
# Episode: 5, Score: -24

# %%
log_path = os.path.join('Training', 'Logs')
model = PPO('MlpPolicy', env, verbose = 1, tensorboard_log = log_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps = 400000)
# Out:
# Logging to Training\Logs\PPO_10
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 19.4     |
# | time/              |          |
# |    fps             | 779      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 20.1         |
# | time/                   |              |
# |    fps                  | 385          |
# |    iterations           | 2            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0142613705 |
# |    clip_fraction        | 0.117        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | -0.000923    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15           |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00689     |
# |    value_loss           | 31.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 21.1        |
# | time/                   |             |
# |    fps                  | 441         |
# |    iterations           | 3           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.007282213 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.00393     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.7        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 31.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 20.1        |
# | time/                   |             |
# |    fps                  | 478         |
# |    iterations           | 4           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010776818 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.0026      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.2        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00434    |
# |    value_loss           | 37.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 21.3        |
# | time/                   |             |
# |    fps                  | 503         |
# |    iterations           | 5           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.013880895 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | -0.00279    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.1        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0222     |
# |    value_loss           | 40.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 25.7        |
# | time/                   |             |
# |    fps                  | 522         |
# |    iterations           | 6           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.009791931 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | -0.000366   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.4        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 36.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 33.8        |
# | time/                   |             |
# |    fps                  | 522         |
# |    iterations           | 7           |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.010131063 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 3.7e-05     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.5        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | 0.00495     |
# |    value_loss           | 37.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 39          |
# | time/                   |             |
# |    fps                  | 536         |
# |    iterations           | 8           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009626265 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 9.17e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.9        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | 0.00212     |
# |    value_loss           | 43.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 39.8        |
# | time/                   |             |
# |    fps                  | 545         |
# |    iterations           | 9           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.018874552 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | -1e-05      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.5        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | 0.00226     |
# |    value_loss           | 55.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 42.5        |
# | time/                   |             |
# |    fps                  | 554         |
# |    iterations           | 10          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.027359929 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.979      |
# |    explained_variance   | 3.66e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.9        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | 0.00246     |
# |    value_loss           | 64.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 44.5         |
# | time/                   |              |
# |    fps                  | 558          |
# |    iterations           | 11           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0073447665 |
# |    clip_fraction        | 0.172        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.978       |
# |    explained_variance   | 2.17e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 29.4         |
# |    n_updates            | 320          |
# |    policy_gradient_loss | 0.00441      |
# |    value_loss           | 68.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 45.5        |
# | time/                   |             |
# |    fps                  | 557         |
# |    iterations           | 12          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.006908505 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.976      |
# |    explained_variance   | -7.15e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39.5        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 0.00655     |
# |    value_loss           | 69.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 44.3        |
# | time/                   |             |
# |    fps                  | 563         |
# |    iterations           | 13          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.014321538 |
# |    clip_fraction        | 0.241       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.948      |
# |    explained_variance   | -1.23e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.7        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | 0.00621     |
# |    value_loss           | 75.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 43.1        |
# | time/                   |             |
# |    fps                  | 568         |
# |    iterations           | 14          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.015532474 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.925      |
# |    explained_variance   | -1.28e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 42          |
# |    n_updates            | 350         |
# |    policy_gradient_loss | 0.00522     |
# |    value_loss           | 78.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 44.5        |
# | time/                   |             |
# |    fps                  | 573         |
# |    iterations           | 15          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.011161704 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.909      |
# |    explained_variance   | -1.97e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 49.9        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.0034      |
# |    value_loss           | 83.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 45.4        |
# | time/                   |             |
# |    fps                  | 570         |
# |    iterations           | 16          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.009741167 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.899      |
# |    explained_variance   | -1.35e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.4        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | 0.00897     |
# |    value_loss           | 81.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 48.3        |
# | time/                   |             |
# |    fps                  | 573         |
# |    iterations           | 17          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.008147348 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.906      |
# |    explained_variance   | -5.72e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 45.6        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | 0.00335     |
# |    value_loss           | 82.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 46.4        |
# | time/                   |             |
# |    fps                  | 577         |
# |    iterations           | 18          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.009861389 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.904      |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.2        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 0.0114      |
# |    value_loss           | 82.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 47.9        |
# | time/                   |             |
# |    fps                  | 580         |
# |    iterations           | 19          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.006873498 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.888      |
# |    explained_variance   | -3.1e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.8        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | 0.00459     |
# |    value_loss           | 83.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 47.8        |
# | time/                   |             |
# |    fps                  | 581         |
# |    iterations           | 20          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.007138434 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.861      |
# |    explained_variance   | -3.7e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.3        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | 0.00416     |
# |    value_loss           | 86.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 50.6         |
# | time/                   |              |
# |    fps                  | 577          |
# |    iterations           | 21           |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0064010103 |
# |    clip_fraction        | 0.173        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.874       |
# |    explained_variance   | -2.26e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34.6         |
# |    n_updates            | 420          |
# |    policy_gradient_loss | 0.00723      |
# |    value_loss           | 89.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 50.6        |
# | time/                   |             |
# |    fps                  | 580         |
# |    iterations           | 22          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.026946478 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.857      |
# |    explained_variance   | -1.31e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 46.8        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | 0.0103      |
# |    value_loss           | 92.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 51          |
# | time/                   |             |
# |    fps                  | 583         |
# |    iterations           | 23          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.014635462 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.836      |
# |    explained_variance   | -1.19e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.8        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 0.0076      |
# |    value_loss           | 95.2        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 51.3       |
# | time/                   |            |
# |    fps                  | 586        |
# |    iterations           | 24         |
# |    time_elapsed         | 83         |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.01353098 |
# |    clip_fraction        | 0.159      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.875     |
# |    explained_variance   | 1.73e-06   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 49.1       |
# |    n_updates            | 450        |
# |    policy_gradient_loss | 0.00135    |
# |    value_loss           | 96.2       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 50.9       |
# | time/                   |            |
# |    fps                  | 588        |
# |    iterations           | 25         |
# |    time_elapsed         | 86         |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.01243207 |
# |    clip_fraction        | 0.17       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.881     |
# |    explained_variance   | 5.96e-08   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 35.8       |
# |    n_updates            | 460        |
# |    policy_gradient_loss | 0.0103     |
# |    value_loss           | 94.4       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 50.8        |
# | time/                   |             |
# |    fps                  | 585         |
# |    iterations           | 26          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.026494252 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.889      |
# |    explained_variance   | 1.37e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 57.3        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | 0.00579     |
# |    value_loss           | 94.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 47.7        |
# | time/                   |             |
# |    fps                  | 584         |
# |    iterations           | 27          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.012767542 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.911      |
# |    explained_variance   | 1.25e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.3        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.00788     |
# |    value_loss           | 97.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 47          |
# | time/                   |             |
# |    fps                  | 585         |
# |    iterations           | 28          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.008387324 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.914      |
# |    explained_variance   | 3.16e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 51          |
# |    n_updates            | 490         |
# |    policy_gradient_loss | 0.00662     |
# |    value_loss           | 89.2        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 43.2       |
# | time/                   |            |
# |    fps                  | 586        |
# |    iterations           | 29         |
# |    time_elapsed         | 101        |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.02376613 |
# |    clip_fraction        | 0.166      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.903     |
# |    explained_variance   | 2.07e-05   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 33.9       |
# |    n_updates            | 500        |
# |    policy_gradient_loss | 0.00513    |
# |    value_loss           | 86.4       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 41.2        |
# | time/                   |             |
# |    fps                  | 587         |
# |    iterations           | 30          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.017686736 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.903      |
# |    explained_variance   | 5.1e-05     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43.1        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00622    |
# |    value_loss           | 84.4        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 35.1       |
# | time/                   |            |
# |    fps                  | 585        |
# |    iterations           | 31         |
# |    time_elapsed         | 108        |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.00937685 |
# |    clip_fraction        | 0.188      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.895     |
# |    explained_variance   | 0.00372    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 38         |
# |    n_updates            | 520        |
# |    policy_gradient_loss | -0.000344  |
# |    value_loss           | 75.4       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 33.4       |
# | time/                   |            |
# |    fps                  | 587        |
# |    iterations           | 32         |
# |    time_elapsed         | 111        |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.03418054 |
# |    clip_fraction        | 0.235      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.877     |
# |    explained_variance   | 0.00779    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 39.3       |
# |    n_updates            | 530        |
# |    policy_gradient_loss | 0.0045     |
# |    value_loss           | 62.7       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 35         |
# | time/                   |            |
# |    fps                  | 589        |
# |    iterations           | 33         |
# |    time_elapsed         | 114        |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.01414869 |
# |    clip_fraction        | 0.205      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.872     |
# |    explained_variance   | 0.00842    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 21.3       |
# |    n_updates            | 540        |
# |    policy_gradient_loss | 0.00187    |
# |    value_loss           | 54.9       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 41.6        |
# | time/                   |             |
# |    fps                  | 590         |
# |    iterations           | 34          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.014532608 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.851      |
# |    explained_variance   | 0.00954     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.3        |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.000272   |
# |    value_loss           | 67.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 48.3        |
# | time/                   |             |
# |    fps                  | 588         |
# |    iterations           | 35          |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.010405352 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.836      |
# |    explained_variance   | 0.00945     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.9        |
# |    n_updates            | 560         |
# |    policy_gradient_loss | 0.00657     |
# |    value_loss           | 68.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 52.3        |
# | time/                   |             |
# |    fps                  | 590         |
# |    iterations           | 36          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.028698388 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.826      |
# |    explained_variance   | 0.00471     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39.5        |
# |    n_updates            | 570         |
# |    policy_gradient_loss | 0.00938     |
# |    value_loss           | 80.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 53.8        |
# | time/                   |             |
# |    fps                  | 591         |
# |    iterations           | 37          |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.024688382 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.821      |
# |    explained_variance   | -0.000161   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 48.6        |
# |    n_updates            | 580         |
# |    policy_gradient_loss | 0.0108      |
# |    value_loss           | 89.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 51.6        |
# | time/                   |             |
# |    fps                  | 591         |
# |    iterations           | 38          |
# |    time_elapsed         | 131         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.009979668 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.78       |
# |    explained_variance   | 7.49e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 46.6        |
# |    n_updates            | 590         |
# |    policy_gradient_loss | 0.012       |
# |    value_loss           | 94.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 48.8        |
# | time/                   |             |
# |    fps                  | 593         |
# |    iterations           | 39          |
# |    time_elapsed         | 134         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.012282122 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.786      |
# |    explained_variance   | 0.000182    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 53.2        |
# |    n_updates            | 600         |
# |    policy_gradient_loss | 0.00432     |
# |    value_loss           | 97.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 49.2         |
# | time/                   |              |
# |    fps                  | 590          |
# |    iterations           | 40           |
# |    time_elapsed         | 138          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0063428935 |
# |    clip_fraction        | 0.128        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.784       |
# |    explained_variance   | 0.00159      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 45.1         |
# |    n_updates            | 610          |
# |    policy_gradient_loss | 0.00473      |
# |    value_loss           | 90.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 51.6        |
# | time/                   |             |
# |    fps                  | 592         |
# |    iterations           | 41          |
# |    time_elapsed         | 141         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.007967177 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.78       |
# |    explained_variance   | 0.00319     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.7        |
# |    n_updates            | 620         |
# |    policy_gradient_loss | 0.00489     |
# |    value_loss           | 96.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 51.8        |
# | time/                   |             |
# |    fps                  | 593         |
# |    iterations           | 42          |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.025385663 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.76       |
# |    explained_variance   | -0.000628   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 50          |
# |    n_updates            | 630         |
# |    policy_gradient_loss | 0.0177      |
# |    value_loss           | 96.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 47.5        |
# | time/                   |             |
# |    fps                  | 594         |
# |    iterations           | 43          |
# |    time_elapsed         | 148         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.017111253 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.732      |
# |    explained_variance   | 0.000272    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 52.9        |
# |    n_updates            | 640         |
# |    policy_gradient_loss | 0.00395     |
# |    value_loss           | 102         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 44.4        |
# | time/                   |             |
# |    fps                  | 595         |
# |    iterations           | 44          |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.011304006 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.69       |
# |    explained_variance   | 0.00294     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.9        |
# |    n_updates            | 650         |
# |    policy_gradient_loss | -0.00354    |
# |    value_loss           | 95.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 35.1        |
# | time/                   |             |
# |    fps                  | 593         |
# |    iterations           | 45          |
# |    time_elapsed         | 155         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.026400682 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.662      |
# |    explained_variance   | 0.0095      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.4        |
# |    n_updates            | 660         |
# |    policy_gradient_loss | 0.00825     |
# |    value_loss           | 83.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 32.6       |
# | time/                   |            |
# |    fps                  | 594        |
# |    iterations           | 46         |
# |    time_elapsed         | 158        |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.03484382 |
# |    clip_fraction        | 0.201      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.649     |
# |    explained_variance   | 0.0208     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 33.4       |
# |    n_updates            | 670        |
# |    policy_gradient_loss | -0.00512   |
# |    value_loss           | 75.3       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 30.8        |
# | time/                   |             |
# |    fps                  | 595         |
# |    iterations           | 47          |
# |    time_elapsed         | 161         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.032021414 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.591      |
# |    explained_variance   | 0.028       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.2        |
# |    n_updates            | 680         |
# |    policy_gradient_loss | 0.00186     |
# |    value_loss           | 66.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 34.8        |
# | time/                   |             |
# |    fps                  | 596         |
# |    iterations           | 48          |
# |    time_elapsed         | 164         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.010309117 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.541      |
# |    explained_variance   | 0.0298      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.4        |
# |    n_updates            | 690         |
# |    policy_gradient_loss | 0.00184     |
# |    value_loss           | 62.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 32.7        |
# | time/                   |             |
# |    fps                  | 597         |
# |    iterations           | 49          |
# |    time_elapsed         | 167         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.021016244 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.522      |
# |    explained_variance   | 0.0504      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33          |
# |    n_updates            | 700         |
# |    policy_gradient_loss | -0.00784    |
# |    value_loss           | 71          |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 36.6       |
# | time/                   |            |
# |    fps                  | 596        |
# |    iterations           | 50         |
# |    time_elapsed         | 171        |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.03929444 |
# |    clip_fraction        | 0.186      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.506     |
# |    explained_variance   | 0.0701     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 36.2       |
# |    n_updates            | 710        |
# |    policy_gradient_loss | -0.00535   |
# |    value_loss           | 70.2       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 44.2        |
# | time/                   |             |
# |    fps                  | 597         |
# |    iterations           | 51          |
# |    time_elapsed         | 174         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.010360799 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.433      |
# |    explained_variance   | -0.0436     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.6        |
# |    n_updates            | 720         |
# |    policy_gradient_loss | 0.0094      |
# |    value_loss           | 67.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 51.4        |
# | time/                   |             |
# |    fps                  | 597         |
# |    iterations           | 52          |
# |    time_elapsed         | 178         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.011483456 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.468      |
# |    explained_variance   | 0.00166     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 47.3        |
# |    n_updates            | 730         |
# |    policy_gradient_loss | 0.0144      |
# |    value_loss           | 75.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 51.2        |
# | time/                   |             |
# |    fps                  | 598         |
# |    iterations           | 53          |
# |    time_elapsed         | 181         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.011232549 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.483      |
# |    explained_variance   | -0.00444    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.1        |
# |    n_updates            | 740         |
# |    policy_gradient_loss | 0.0106      |
# |    value_loss           | 92.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 51.9        |
# | time/                   |             |
# |    fps                  | 598         |
# |    iterations           | 54          |
# |    time_elapsed         | 184         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.068736665 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.52       |
# |    explained_variance   | -0.000405   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44.6        |
# |    n_updates            | 750         |
# |    policy_gradient_loss | 0.0144      |
# |    value_loss           | 99.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 54.2        |
# | time/                   |             |
# |    fps                  | 598         |
# |    iterations           | 55          |
# |    time_elapsed         | 188         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.009318023 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.539      |
# |    explained_variance   | -0.000113   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 45          |
# |    n_updates            | 760         |
# |    policy_gradient_loss | 0.00675     |
# |    value_loss           | 101         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# ...
# |    policy_gradient_loss | 0.00965     |
# |    value_loss           | 108         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 50.3       |
# | time/                   |            |
# |    fps                  | 597        |
# |    iterations           | 179        |
# |    time_elapsed         | 613        |
# |    total_timesteps      | 366592     |
# | train/                  |            |
# |    approx_kl            | 0.02814826 |
# |    clip_fraction        | 0.0989     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.252     |
# |    explained_variance   | 0.074      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 62.5       |
# |    n_updates            | 2000       |
# |    policy_gradient_loss | -0.00555   |
# |    value_loss           | 116        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 50.4        |
# | time/                   |             |
# |    fps                  | 596         |
# |    iterations           | 180         |
# |    time_elapsed         | 618         |
# |    total_timesteps      | 368640      |
# | train/                  |             |
# |    approx_kl            | 0.004788936 |
# |    clip_fraction        | 0.0495      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.218      |
# |    explained_variance   | -0.0197     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 80.7        |
# |    n_updates            | 2010        |
# |    policy_gradient_loss | 0.0075      |
# |    value_loss           | 96.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 51.2        |
# | time/                   |             |
# |    fps                  | 596         |
# |    iterations           | 181         |
# |    time_elapsed         | 621         |
# |    total_timesteps      | 370688      |
# | train/                  |             |
# |    approx_kl            | 0.031025764 |
# |    clip_fraction        | 0.0614      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.208      |
# |    explained_variance   | 0.0131      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 48          |
# |    n_updates            | 2020        |
# |    policy_gradient_loss | 0.0105      |
# |    value_loss           | 103         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 50.5         |
# | time/                   |              |
# |    fps                  | 596          |
# |    iterations           | 182          |
# |    time_elapsed         | 625          |
# |    total_timesteps      | 372736       |
# | train/                  |              |
# |    approx_kl            | 0.0077930437 |
# |    clip_fraction        | 0.06         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.231       |
# |    explained_variance   | 0.0597       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 51.6         |
# |    n_updates            | 2030         |
# |    policy_gradient_loss | 0.00141      |
# |    value_loss           | 113          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 50.8        |
# | time/                   |             |
# |    fps                  | 596         |
# |    iterations           | 183         |
# |    time_elapsed         | 628         |
# |    total_timesteps      | 374784      |
# | train/                  |             |
# |    approx_kl            | 0.028143093 |
# |    clip_fraction        | 0.0712      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.23       |
# |    explained_variance   | -0.0193     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.3        |
# |    n_updates            | 2040        |
# |    policy_gradient_loss | 0.0143      |
# |    value_loss           | 96.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 53.6        |
# | time/                   |             |
# |    fps                  | 596         |
# |    iterations           | 184         |
# |    time_elapsed         | 631         |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.060015965 |
# |    clip_fraction        | 0.0713      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.209      |
# |    explained_variance   | -0.00445    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 53.9        |
# |    n_updates            | 2050        |
# |    policy_gradient_loss | 0.012       |
# |    value_loss           | 103         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 49.4        |
# | time/                   |             |
# |    fps                  | 596         |
# |    iterations           | 185         |
# |    time_elapsed         | 635         |
# |    total_timesteps      | 378880      |
# | train/                  |             |
# |    approx_kl            | 0.032506675 |
# |    clip_fraction        | 0.0437      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.174      |
# |    explained_variance   | 0.00461     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 55.9        |
# |    n_updates            | 2060        |
# |    policy_gradient_loss | 0.0127      |
# |    value_loss           | 108         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 36.9       |
# | time/                   |            |
# |    fps                  | 596        |
# |    iterations           | 186        |
# |    time_elapsed         | 639        |
# |    total_timesteps      | 380928     |
# | train/                  |            |
# |    approx_kl            | 0.07914228 |
# |    clip_fraction        | 0.0909     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.184     |
# |    explained_variance   | -0.0504    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 59.5       |
# |    n_updates            | 2070       |
# |    policy_gradient_loss | 0.0054     |
# |    value_loss           | 128        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 30.6       |
# | time/                   |            |
# |    fps                  | 596        |
# |    iterations           | 187        |
# |    time_elapsed         | 642        |
# |    total_timesteps      | 382976     |
# | train/                  |            |
# |    approx_kl            | 0.26150137 |
# |    clip_fraction        | 0.225      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.241     |
# |    explained_variance   | -0.09      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 94.5       |
# |    n_updates            | 2080       |
# |    policy_gradient_loss | -0.00473   |
# |    value_loss           | 190        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 22.8        |
# | time/                   |             |
# |    fps                  | 596         |
# |    iterations           | 188         |
# |    time_elapsed         | 645         |
# |    total_timesteps      | 385024      |
# | train/                  |             |
# |    approx_kl            | 0.088116035 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.233      |
# |    explained_variance   | -0.107      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 65.1        |
# |    n_updates            | 2090        |
# |    policy_gradient_loss | -0.0126     |
# |    value_loss           | 145         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 30.4        |
# | time/                   |             |
# |    fps                  | 595         |
# |    iterations           | 189         |
# |    time_elapsed         | 649         |
# |    total_timesteps      | 387072      |
# | train/                  |             |
# |    approx_kl            | 0.011836307 |
# |    clip_fraction        | 0.0999      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.175      |
# |    explained_variance   | -0.0186     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 73.9        |
# |    n_updates            | 2100        |
# |    policy_gradient_loss | 0.00542     |
# |    value_loss           | 161         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 31.6        |
# | time/                   |             |
# |    fps                  | 595         |
# |    iterations           | 190         |
# |    time_elapsed         | 653         |
# |    total_timesteps      | 389120      |
# | train/                  |             |
# |    approx_kl            | 0.073083095 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.19       |
# |    explained_variance   | 0.135       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.4        |
# |    n_updates            | 2110        |
# |    policy_gradient_loss | -0.0159     |
# |    value_loss           | 87.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 40.2        |
# | time/                   |             |
# |    fps                  | 595         |
# |    iterations           | 191         |
# |    time_elapsed         | 656         |
# |    total_timesteps      | 391168      |
# | train/                  |             |
# |    approx_kl            | 0.088056475 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.194      |
# |    explained_variance   | -0.25       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 60.6        |
# |    n_updates            | 2120        |
# |    policy_gradient_loss | 0.00404     |
# |    value_loss           | 118         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 43.7        |
# | time/                   |             |
# |    fps                  | 595         |
# |    iterations           | 192         |
# |    time_elapsed         | 659         |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.012386631 |
# |    clip_fraction        | 0.0613      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.183      |
# |    explained_variance   | -0.00244    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 46.2        |
# |    n_updates            | 2130        |
# |    policy_gradient_loss | 0.00685     |
# |    value_loss           | 103         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 48.2         |
# | time/                   |              |
# |    fps                  | 596          |
# |    iterations           | 193          |
# |    time_elapsed         | 663          |
# |    total_timesteps      | 395264       |
# | train/                  |              |
# |    approx_kl            | 0.0002528998 |
# |    clip_fraction        | 0.0258       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.157       |
# |    explained_variance   | 0.0285       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23.8         |
# |    n_updates            | 2140         |
# |    policy_gradient_loss | 0.00373      |
# |    value_loss           | 74.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 51.2        |
# | time/                   |             |
# |    fps                  | 595         |
# |    iterations           | 194         |
# |    time_elapsed         | 667         |
# |    total_timesteps      | 397312      |
# | train/                  |             |
# |    approx_kl            | 0.007212678 |
# |    clip_fraction        | 0.0262      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.167      |
# |    explained_variance   | 0.0549      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 45.8        |
# |    n_updates            | 2150        |
# |    policy_gradient_loss | 0.000663    |
# |    value_loss           | 88          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 50.5        |
# | time/                   |             |
# |    fps                  | 595         |
# |    iterations           | 195         |
# |    time_elapsed         | 670         |
# |    total_timesteps      | 399360      |
# | train/                  |             |
# |    approx_kl            | 0.005794399 |
# |    clip_fraction        | 0.048       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.176      |
# |    explained_variance   | -0.109      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 57.1        |
# |    n_updates            | 2160        |
# |    policy_gradient_loss | 0.00869     |
# |    value_loss           | 93.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 51.7        |
# | time/                   |             |
# |    fps                  | 595         |
# |    iterations           | 196         |
# |    time_elapsed         | 674         |
# |    total_timesteps      | 401408      |
# | train/                  |             |
# |    approx_kl            | 0.005462073 |
# |    clip_fraction        | 0.0493      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.187      |
# |    explained_variance   | -0.00491    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 45.1        |
# |    n_updates            | 2170        |
# |    policy_gradient_loss | 0.00918     |
# |    value_loss           | 102         |
# -----------------------------------------

# %%
shower_path = os.path.join('Training', 'saved_model','Shower_model_ppo')

# %%
model.save(shower_path)

# %%
evaluate_policy(model,env,n_eval_episodes = 1000)
# Out:
# (-8.52, 59.39199946120689)
